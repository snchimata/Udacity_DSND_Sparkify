# %% [markdown]
# # Sparkify Project Workspace
# This workspace contains a tiny subset (128MB) of the full dataset available (12GB). Feel free to use this workspace to build your project, or to explore a smaller subset with Spark before deploying your cluster on the cloud. Instructions for setting up your Spark cluster is included in the last lesson of the Extracurricular Spark Course content.
#
# You can follow the steps below to guide your data analysis and model building portion of this project.

# %%
# import libraries
#!pip install --upgrade --force-reinstall pyspark
#!pip install --upgrade --force-reinstall pandas
#!pip install pandas-compat
#!pip install koalas
#!pip install --upgrade --force-reinstall pyarrow
#import pandas_compat
#import databricks.koalas as ks


from pyspark.sql import SparkSession, Window
import pyspark.sql.functions as f
from pyspark.sql.functions import isnan,isnull, count,countDistinct, when, col, desc, udf, col, sort_array, asc, avg
from pyspark.sql import Row
from pyspark.ml.evaluation import MulticlassClassificationEvaluator
from pyspark.sql.window import Window
from pyspark.sql.types import IntegerType, DateType
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
import time
# %matplotlib inline
from pyspark.ml.feature import StandardScaler, StringIndexer, VectorAssembler,OneHotEncoderEstimator
from pyspark.ml.tuning import CrossValidator, ParamGridBuilder
from pyspark.ml import Pipeline
from pyspark.ml.classification import LogisticRegression, RandomForestClassifier, GBTClassifier;

# %%
# create a Spark session
spark = SparkSession \
    .builder \
    .appName("Sparkify") \
    .getOrCreate()

# %% [markdown]
# # Load and Clean Dataset
# In this workspace, the mini-dataset file is `mini_sparkify_event_data.json`. Load and clean the dataset, checking for invalid or missing data - for example, records without userids or sessionids.

# %%
df = spark.read.json("mini_sparkify_event_data.json")

# %%
df.first()
# Out:
# Row(artist='Martha Tilston', auth='Logged In', firstName='Colin', gender='M', itemInSession=50, lastName='Freeman', length=277.89016, level='paid', location='Bakersfield, CA', method='PUT', page='NextSong', registration=1538173362000, sessionId=29, song='Rockpools', status=200, ts=1538352117000, userAgent='Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) Gecko/20100101 Firefox/31.0', userId='30')

# %%
df.describe()#.toPandas()#.transpose()
# Out:
# DataFrame[summary: string, artist: string, auth: string, firstName: string, gender: string, itemInSession: string, lastName: string, length: string, level: string, location: string, method: string, page: string, registration: string, sessionId: string, song: string, status: string, ts: string, userAgent: string, userId: string]

# %%
df.printSchema()
# Out:
# root
#  |-- artist: string (nullable = true)
#  |-- auth: string (nullable = true)
#  |-- firstName: string (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- itemInSession: long (nullable = true)
#  |-- lastName: string (nullable = true)
#  |-- length: double (nullable = true)
#  |-- level: string (nullable = true)
#  |-- location: string (nullable = true)
#  |-- method: string (nullable = true)
#  |-- page: string (nullable = true)
#  |-- registration: long (nullable = true)
#  |-- sessionId: long (nullable = true)
#  |-- song: string (nullable = true)
#  |-- status: long (nullable = true)
#  |-- ts: long (nullable = true)
#  |-- userAgent: string (nullable = true)
#  |-- userId: string (nullable = true)

# %%
print("Shape")
print((df.count(), len(df.columns)))
# Out:
# Shape
# (286500, 18)

# %% [markdown]
# Check Invalid or missing data

# %%
df.filter(df.sessionId == '').count()
# Out:
# 0

# %%
df.filter(df.userId == '').count()
# Out:
# 8346

# %% [markdown]
# Null entries count by column

# %%
df.select([count(when(isnull(c), c)).alias(c) for c in df.columns]).show()
# Out:
# +------+----+---------+------+-------------+--------+------+-----+--------+------+----+------------+---------+-----+------+---+---------+------+
# |artist|auth|firstName|gender|itemInSession|lastName|length|level|location|method|page|registration|sessionId| song|status| ts|userAgent|userId|
# +------+----+---------+------+-------------+--------+------+-----+--------+------+----+------------+---------+-----+------+---+---------+------+
# | 58392|   0|     8346|  8346|            0|    8346| 58392|    0|    8346|     0|   0|        8346|        0|58392|     0|  0|     8346|     0|
# +------+----+---------+------+-------------+--------+------+-----+--------+------+----+------------+---------+-----+------+---+---------+------+

# %%
# drop NAs in columns userId, sessionId and blanks ins userId
df = df.dropna(how = 'any', subset = ['userId', 'sessionId'])
df = df.filter(df['userId'] != '')

# %% [markdown]
# # Exploratory Data Analysis
# When you're working with the full dataset, perform EDA by loading a small subset of the data and doing basic manipulations within Spark. In this workspace, you are already provided a small subset of data you can explore.
#
# ### Define Churn
#
# Once you've done some preliminary analysis, create a column `Churn` to use as the label for your model. I suggest using the `Cancellation Confirmation` events to define your churn, which happen for both paid and free users. As a bonus task, you can also look into the `Downgrade` events.
#
# ### Explore Data
# Once you've defined churn, perform some exploratory data analysis to observe the behavior for users who stayed vs users who churned. You can start by exploring aggregates on these two groups of users, observing how much of a specific action they experienced per a certain time unit or number of songs played.

# %% [markdown]
# Explore Page feature with Cancellation confirmation for sense making on churn

# %%
df.select('page','UserId').groupby('page').agg({'page':'count'}).select('page','count(page)').show()
# Out:
# +--------------------+-----------+
# |                page|count(page)|
# +--------------------+-----------+
# |              Cancel|         52|
# |    Submit Downgrade|         63|
# |         Thumbs Down|       2546|
# |                Home|      10082|
# |           Downgrade|       2055|
# |         Roll Advert|       3933|
# |              Logout|       3226|
# |       Save Settings|        310|
# |Cancellation Conf...|         52|
# |               About|        495|
# |            Settings|       1514|
# |     Add to Playlist|       6526|
# |          Add Friend|       4277|
# |            NextSong|     228108|
# |           Thumbs Up|      12551|
# |                Help|       1454|
# |             Upgrade|        499|
# |               Error|        252|
# |      Submit Upgrade|        159|
# +--------------------+-----------+

# %% [markdown]
# Verify Data

# %%
df.filter(df["page"] == 'Cancellation Confirmation').first()
# Out:
# Row(artist=None, auth='Cancelled', firstName='Adriel', gender='M', itemInSession=104, lastName='Mendoza', length=None, level='paid', location='Kansas City, MO-KS', method='GET', page='Cancellation Confirmation', registration=1535623466000, sessionId=514, song=None, status=200, ts=1538943990000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"', userId='18')

# %% [markdown]
# ## Churn
# The churn rate, also known as the rate of attrition or customer churn, is the rate at which customers stop doing business with an entity.
#
# Users who visited cancellation confirmation can be considered as churned users. Aditionally submit downgrade page vistors can also be considered for further reasearch.
#
# Create a column churn by an user defined function which flags churned user with 1.

# %%
# Churn is a label for Cancelled user
# Create a user defined function
flag_cancelation_confirmation = udf(lambda x: 1 if x == "Cancellation Confirmation" else 0, IntegerType())
df = df.withColumn("churn", flag_cancelation_confirmation("page"))
#Define window bounds
windowval = Window.partitionBy("userId").rangeBetween(Window.unboundedPreceding, Window.unboundedFollowing)
# window function
df = df.withColumn("churn", f.sum("churn").over(windowval))

# %%
df.toPandas()
# Out:
#                                           artist       auth firstName gender  \
# 0                           Sleeping With Sirens  Logged In  Darianna      F
# 1                          Francesca Battistelli  Logged In  Darianna      F
# 2                                         Brutha  Logged In  Darianna      F
# 3                                           None  Logged In  Darianna      F
# 4                                    Josh Ritter  Logged In  Darianna      F
# 5                                          LMFAO  Logged In  Darianna      F
# 6                                    OneRepublic  Logged In  Darianna      F
# 7                                  Dwight Yoakam  Logged In  Darianna      F
# 8                                           None  Logged In  Darianna      F
# 9                                 The Chordettes  Logged In  Darianna      F
# 10                  Coko featuring Kirk Franklin  Logged In  Darianna      F
# 11                                      The Cure  Logged In  Darianna      F
# 12                                          None  Logged In  Darianna      F
# 13                          Kid Cudi Vs Crookers  Logged In  Darianna      F
# 14                                          None  Logged In  Darianna      F
# 15                                      Yeasayer  Logged In  Darianna      F
# 16                                       Ben Lee  Logged In  Darianna      F
# 17                                          None  Logged In  Darianna      F
# 18                            ? & The Mysterians  Logged In  Darianna      F
# 19                                          None  Logged In  Darianna      F
# 20                           Angels and Airwaves  Logged In  Darianna      F
# 21                                          None  Logged In  Darianna      F
# 22                                      Karramba  Logged In  Darianna      F
# 23                                   Biffy Clyro  Logged In  Darianna      F
# 24               Dr. Dre / Eminem / Alvin Joiner  Logged In  Darianna      F
# 25                                         Tamia  Logged In  Darianna      F
# 26                               Stanislaw Soyka  Logged In  Darianna      F
# 27                                      fIREHOSE  Logged In  Darianna      F
# 28                                Marilyn Manson  Logged In  Darianna      F
# 29                                        Redman  Logged In  Darianna      F
# ...                                          ...        ...       ...    ...
# 278124                                      None  Logged In   Delaney      F
# 278125                                 The Clash  Logged In   Delaney      F
# 278126                                Air France  Logged In   Delaney      F
# 278127                                  New Boyz  Logged In   Delaney      F
# 278128                               Snow Patrol  Logged In   Delaney      F
# 278129                                 The Shins  Logged In   Delaney      F
# 278130                             Dwight Yoakam  Logged In   Delaney      F
# 278131                          Five Iron Frenzy  Logged In   Delaney      F
# 278132                               John Powell  Logged In   Delaney      F
# 278133                                      None  Logged In   Delaney      F
# 278134                                      None  Logged In   Delaney      F
# 278135                              Matt Pond PA  Logged In   Delaney      F
# 278136                            Peter Frampton  Logged In   Delaney      F
# 278137                     Beanfield feat. Bajka  Logged In   Delaney      F
# 278138  Sopor Aeternus & The Ensemble Of Shadows  Logged In   Delaney      F
# 278139                                  Sanalejo  Logged In   Delaney      F
# 278140                               Sheryl Crow  Logged In   Delaney      F
# 278141                      Peter Bjorn And John  Logged In   Delaney      F
# 278142                                      None  Logged In   Delaney      F
# 278143                                  Natiruts  Logged In   Delaney      F
# 278144                                      None  Logged In   Delaney      F
# 278145                            Bebel Gilberto  Logged In   Delaney      F
# 278146     Michael BublÃÂ© (With Nelly Furtado)  Logged In   Delaney      F
# 278147                                 Lady GaGa  Logged In   Delaney      F
# 278148                                      None  Logged In   Delaney      F
# 278149                                      None  Logged In   Delaney      F
# 278150                                  Harmonia  Logged In   Delaney      F
# 278151                                      None  Logged In   Delaney      F
# 278152                                      None  Logged In   Delaney      F
# 278153                                      None  Cancelled   Delaney      F
#
#         itemInSession   lastName     length level  \
# 0                   0  Carpenter  202.97098  free
# 1                   1  Carpenter  196.54485  free
# 2                   2  Carpenter  263.13098  free
# 3                   3  Carpenter        NaN  free
# 4                   4  Carpenter  316.23791  free
# 5                   5  Carpenter  183.74485  free
# 6                   6  Carpenter  224.67873  free
# 7                   7  Carpenter  239.30730  free
# 8                   8  Carpenter        NaN  free
# 9                   9  Carpenter  142.41914  free
# 10                 10  Carpenter  249.31220  free
# 11                 11  Carpenter   52.27057  free
# 12                 12  Carpenter        NaN  free
# 13                 13  Carpenter  162.97751  free
# 14                 14  Carpenter        NaN  free
# 15                 15  Carpenter  323.44771  free
# 16                 16  Carpenter  245.78567  free
# 17                 17  Carpenter        NaN  free
# 18                 18  Carpenter  128.10404  free
# 19                 19  Carpenter        NaN  free
# 20                 20  Carpenter  302.05342  free
# 21                 21  Carpenter        NaN  free
# 22                 22  Carpenter  177.10975  free
# 23                 23  Carpenter  203.33669  free
# 24                 24  Carpenter  244.21832  free
# 25                 25  Carpenter  243.09506  free
# 26                 26  Carpenter  115.30404  free
# 27                 27  Carpenter   99.23873  free
# 28                 28  Carpenter  338.18077  free
# 29                 29  Carpenter  250.72281  free
# ...               ...        ...        ...   ...
# 278124             41      Perez        NaN  free
# 278125             42      Perez  263.20934  free
# 278126             43      Perez  318.58893  free
# 278127             44      Perez  178.80771  free
# 278128             45      Perez  256.31302  free
# 278129             46      Perez  268.32934  free
# 278130             47      Perez  239.30730  free
# 278131             48      Perez  236.09424  free
# 278132             49      Perez  189.85751  free
# 278133             50      Perez        NaN  free
# 278134              2      Perez        NaN  free
# 278135              3      Perez  173.21751  free
# 278136              4      Perez  471.69261  free
# 278137              5      Perez  594.20689  free
# 278138              6      Perez  177.08363  free
# 278139              7      Perez  222.45832  free
# 278140              8      Perez  333.68771  free
# 278141              9      Perez  231.18322  free
# 278142             10      Perez        NaN  free
# 278143             11      Perez  210.88608  free
# 278144             12      Perez        NaN  free
# 278145             13      Perez  280.99873  free
# 278146             14      Perez  284.36853  free
# 278147             15      Perez  274.18077  free
# 278148             16      Perez        NaN  free
# 278149             19      Perez        NaN  free
# 278150             20      Perez  655.77751  free
# 278151             21      Perez        NaN  free
# 278152             22      Perez        NaN  free
# 278153             23      Perez        NaN  free
#
#                                          location method  \
# 0                 Bridgeport-Stamford-Norwalk, CT    PUT
# 1                 Bridgeport-Stamford-Norwalk, CT    PUT
# 2                 Bridgeport-Stamford-Norwalk, CT    PUT
# 3                 Bridgeport-Stamford-Norwalk, CT    PUT
# 4                 Bridgeport-Stamford-Norwalk, CT    PUT
# 5                 Bridgeport-Stamford-Norwalk, CT    PUT
# 6                 Bridgeport-Stamford-Norwalk, CT    PUT
# 7                 Bridgeport-Stamford-Norwalk, CT    PUT
# 8                 Bridgeport-Stamford-Norwalk, CT    GET
# 9                 Bridgeport-Stamford-Norwalk, CT    PUT
# 10                Bridgeport-Stamford-Norwalk, CT    PUT
# 11                Bridgeport-Stamford-Norwalk, CT    PUT
# 12                Bridgeport-Stamford-Norwalk, CT    GET
# 13                Bridgeport-Stamford-Norwalk, CT    PUT
# 14                Bridgeport-Stamford-Norwalk, CT    PUT
# 15                Bridgeport-Stamford-Norwalk, CT    PUT
# 16                Bridgeport-Stamford-Norwalk, CT    PUT
# 17                Bridgeport-Stamford-Norwalk, CT    GET
# 18                Bridgeport-Stamford-Norwalk, CT    PUT
# 19                Bridgeport-Stamford-Norwalk, CT    GET
# 20                Bridgeport-Stamford-Norwalk, CT    PUT
# 21                Bridgeport-Stamford-Norwalk, CT    GET
# 22                Bridgeport-Stamford-Norwalk, CT    PUT
# 23                Bridgeport-Stamford-Norwalk, CT    PUT
# 24                Bridgeport-Stamford-Norwalk, CT    PUT
# 25                Bridgeport-Stamford-Norwalk, CT    PUT
# 26                Bridgeport-Stamford-Norwalk, CT    PUT
# 27                Bridgeport-Stamford-Norwalk, CT    PUT
# 28                Bridgeport-Stamford-Norwalk, CT    PUT
# 29                Bridgeport-Stamford-Norwalk, CT    PUT
# ...                                           ...    ...
# 278124  Miami-Fort Lauderdale-West Palm Beach, FL    GET
# 278125  Miami-Fort Lauderdale-West Palm Beach, FL    PUT
# 278126  Miami-Fort Lauderdale-West Palm Beach, FL    PUT
# 278127  Miami-Fort Lauderdale-West Palm Beach, FL    PUT
# 278128  Miami-Fort Lauderdale-West Palm Beach, FL    PUT
# 278129  Miami-Fort Lauderdale-West Palm Beach, FL    PUT
# 278130  Miami-Fort Lauderdale-West Palm Beach, FL    PUT
# 278131  Miami-Fort Lauderdale-West Palm Beach, FL    PUT
# 278132  Miami-Fort Lauderdale-West Palm Beach, FL    PUT
# 278133  Miami-Fort Lauderdale-West Palm Beach, FL    PUT
# 278134  Miami-Fort Lauderdale-West Palm Beach, FL    GET
# 278135  Miami-Fort Lauderdale-West Palm Beach, FL    PUT
# 278136  Miami-Fort Lauderdale-West Palm Beach, FL    PUT
# 278137  Miami-Fort Lauderdale-West Palm Beach, FL    PUT
# 278138  Miami-Fort Lauderdale-West Palm Beach, FL    PUT
# 278139  Miami-Fort Lauderdale-West Palm Beach, FL    PUT
# 278140  Miami-Fort Lauderdale-West Palm Beach, FL    PUT
# 278141  Miami-Fort Lauderdale-West Palm Beach, FL    PUT
# 278142  Miami-Fort Lauderdale-West Palm Beach, FL    GET
# 278143  Miami-Fort Lauderdale-West Palm Beach, FL    PUT
# 278144  Miami-Fort Lauderdale-West Palm Beach, FL    GET
# 278145  Miami-Fort Lauderdale-West Palm Beach, FL    PUT
# 278146  Miami-Fort Lauderdale-West Palm Beach, FL    PUT
# 278147  Miami-Fort Lauderdale-West Palm Beach, FL    PUT
# 278148  Miami-Fort Lauderdale-West Palm Beach, FL    PUT
# 278149  Miami-Fort Lauderdale-West Palm Beach, FL    GET
# 278150  Miami-Fort Lauderdale-West Palm Beach, FL    PUT
# 278151  Miami-Fort Lauderdale-West Palm Beach, FL    GET
# 278152  Miami-Fort Lauderdale-West Palm Beach, FL    PUT
# 278153  Miami-Fort Lauderdale-West Palm Beach, FL    GET
#
#                              page   registration  sessionId  \
# 0                        NextSong  1538016340000         31
# 1                        NextSong  1538016340000         31
# 2                        NextSong  1538016340000         31
# 3                       Thumbs Up  1538016340000         31
# 4                        NextSong  1538016340000         31
# 5                        NextSong  1538016340000         31
# 6                        NextSong  1538016340000         31
# 7                        NextSong  1538016340000         31
# 8                     Roll Advert  1538016340000         31
# 9                        NextSong  1538016340000         31
# 10                       NextSong  1538016340000         31
# 11                       NextSong  1538016340000         31
# 12                    Roll Advert  1538016340000         31
# 13                       NextSong  1538016340000         31
# 14                      Thumbs Up  1538016340000         31
# 15                       NextSong  1538016340000         31
# 16                       NextSong  1538016340000         31
# 17                    Roll Advert  1538016340000         31
# 18                       NextSong  1538016340000         31
# 19                    Roll Advert  1538016340000         31
# 20                       NextSong  1538016340000         31
# 21                    Roll Advert  1538016340000         31
# 22                       NextSong  1538016340000         31
# 23                       NextSong  1538016340000         31
# 24                       NextSong  1538016340000         31
# 25                       NextSong  1538016340000         31
# 26                       NextSong  1538016340000         31
# 27                       NextSong  1538016340000         31
# 28                       NextSong  1538016340000         31
# 29                       NextSong  1538016340000         31
# ...                           ...            ...        ...
# 278124                      Error  1534627466000         51
# 278125                   NextSong  1534627466000         51
# 278126                   NextSong  1534627466000         51
# 278127                   NextSong  1534627466000         51
# 278128                   NextSong  1534627466000         51
# 278129                   NextSong  1534627466000         51
# 278130                   NextSong  1534627466000         51
# 278131                   NextSong  1534627466000         51
# 278132                   NextSong  1534627466000         51
# 278133                     Logout  1534627466000         51
# 278134                       Home  1534627466000         53
# 278135                   NextSong  1534627466000         53
# 278136                   NextSong  1534627466000         53
# 278137                   NextSong  1534627466000         53
# 278138                   NextSong  1534627466000         53
# 278139                   NextSong  1534627466000         53
# 278140                   NextSong  1534627466000         53
# 278141                   NextSong  1534627466000         53
# 278142                Roll Advert  1534627466000         53
# 278143                   NextSong  1534627466000         53
# 278144                       Help  1534627466000         53
# 278145                   NextSong  1534627466000         53
# 278146                   NextSong  1534627466000         53
# 278147                   NextSong  1534627466000         53
# 278148                     Logout  1534627466000         53
# 278149                       Home  1534627466000         53
# 278150                   NextSong  1534627466000         53
# 278151                Roll Advert  1534627466000         53
# 278152                     Cancel  1534627466000         53
# 278153  Cancellation Confirmation  1534627466000         53
#
#                                                      song  status  \
# 0               Captain Tyin Knots VS Mr Walkway (No Way)     200
# 1                            Beautiful_ Beautiful (Album)     200
# 2                                              She's Gone     200
# 3                                                    None     307
# 4                                          Folk Bloodbath     200
# 5                                                     Yes     200
# 6                                                 Secrets     200
# 7                                          You're The One     200
# 8                                                    None     200
# 9                                              Mr Sandman     200
# 10                                              I Get Joy     200
# 11                                        The Final Sound     200
# 12                                                   None     200
# 13                                           Day 'N' Nite     200
# 14                                                   None     307
# 15                                                   2080     200
# 16                                           Ache For You     200
# 17                                                   None     200
# 18                                       Just Like A Rose     200
# 19                                                   None     200
# 20                                               The Gift     200
# 21                                                   None     200
# 22                                           Erni & Berni     200
# 23                                              Mountains     200
# 24                                  What's The Difference     200
# 25                 Officially Missing You (Radio Version)     200
# 26                                          W Zlobie Lezy     200
# 27                                             It Matters     200
# 28                                             Coma White     200
# 29                                           Rock Da Spot     200
# ...                                                   ...     ...
# 278124                                               None     404
# 278125                                     Hitsville U.K.     200
# 278126                                      Never Content     200
# 278127  Tie Me Down [feat. Ray J] (Amended Album Version)     200
# 278128                        The Planets Bend Between Us     200
# 278129                                 Mild Child (Album)     200
# 278130                                     You're The One     200
# 278131                                             Canada     200
# 278132                                     Rescuing Penny     200
# 278133                                               None     307
# 278134                                               None     200
# 278135                                    KC (LP Version)     200
# 278136                                 Most Of All (Live)     200
# 278137                            Tides (C's Movement #1)     200
# 278138                                   La Mort d'Arthur     200
# 278139                                            Amapola     200
# 278140                                    I Shall Believe     200
# 278141                                         Paris 2004     200
# 278142                                               None     200
# 278143                   Jamaica Roots II(Agora E Sempre)     200
# 278144                                               None     200
# 278145                                    Samba Da Bencao     200
# 278146             Quando_ Quando_ Quando (Album Version)     200
# 278147                                          Alejandro     200
# 278148                                               None     307
# 278149                                               None     200
# 278150                                      Sehr kosmisch     200
# 278151                                               None     200
# 278152                                               None     307
# 278153                                               None     200
#
#                    ts                                          userAgent  \
# 0       1539003534000  "Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like...
# 1       1539003736000  "Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like...
# 2       1539003932000  "Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like...
# 3       1539003933000  "Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like...
# 4       1539004195000  "Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like...
# 5       1539004511000  "Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like...
# 6       1539004694000  "Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like...
# 7       1539004918000  "Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like...
# 8       1539004961000  "Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like...
# 9       1539005157000  "Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like...
# 10      1539005299000  "Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like...
# 11      1539005548000  "Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like...
# 12      1539005571000  "Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like...
# 13      1539005600000  "Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like...
# 14      1539005601000  "Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like...
# 15      1539005762000  "Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like...
# 16      1539006085000  "Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like...
# 17      1539006103000  "Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like...
# 18      1539006330000  "Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like...
# 19      1539006331000  "Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like...
# 20      1539006458000  "Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like...
# 21      1539006503000  "Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like...
# 22      1539006760000  "Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like...
# 23      1539006937000  "Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like...
# 24      1539007140000  "Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like...
# 25      1539007384000  "Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like...
# 26      1539007627000  "Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like...
# 27      1539007742000  "Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like...
# 28      1539007841000  "Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like...
# 29      1539008179000  "Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like...
# ...               ...                                                ...
# 278124  1538489901000  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_6_8...
# 278125  1538490278000  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_6_8...
# 278126  1538490541000  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_6_8...
# 278127  1538490859000  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_6_8...
# 278128  1538491037000  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_6_8...
# 278129  1538491293000  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_6_8...
# 278130  1538491561000  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_6_8...
# 278131  1538491800000  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_6_8...
# 278132  1538492036000  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_6_8...
# 278133  1538492037000  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_6_8...
# 278134  1538494425000  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_6_8...
# 278135  1538494783000  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_6_8...
# 278136  1538494956000  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_6_8...
# 278137  1538495427000  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_6_8...
# 278138  1538496021000  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_6_8...
# 278139  1538496198000  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_6_8...
# 278140  1538496420000  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_6_8...
# 278141  1538496753000  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_6_8...
# 278142  1538496839000  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_6_8...
# 278143  1538496984000  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_6_8...
# 278144  1538497010000  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_6_8...
# 278145  1538497194000  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_6_8...
# 278146  1538497474000  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_6_8...
# 278147  1538497758000  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_6_8...
# 278148  1538497759000  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_6_8...
# 278149  1538497786000  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_6_8...
# 278150  1538498032000  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_6_8...
# 278151  1538498073000  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_6_8...
# 278152  1538498074000  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_6_8...
# 278153  1538498205000  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_6_8...
#
#         userId  churn
# 0       100010      0
# 1       100010      0
# 2       100010      0
# 3       100010      0
# 4       100010      0
# 5       100010      0
# 6       100010      0
# 7       100010      0
# 8       100010      0
# 9       100010      0
# 10      100010      0
# 11      100010      0
# 12      100010      0
# 13      100010      0
# 14      100010      0
# 15      100010      0
# 16      100010      0
# 17      100010      0
# 18      100010      0
# 19      100010      0
# 20      100010      0
# 21      100010      0
# 22      100010      0
# 23      100010      0
# 24      100010      0
# 25      100010      0
# 26      100010      0
# 27      100010      0
# 28      100010      0
# 29      100010      0
# ...        ...    ...
# 278124  100001      1
# 278125  100001      1
# 278126  100001      1
# 278127  100001      1
# 278128  100001      1
# 278129  100001      1
# 278130  100001      1
# 278131  100001      1
# 278132  100001      1
# 278133  100001      1
# 278134  100001      1
# 278135  100001      1
# 278136  100001      1
# 278137  100001      1
# 278138  100001      1
# 278139  100001      1
# 278140  100001      1
# 278141  100001      1
# 278142  100001      1
# 278143  100001      1
# 278144  100001      1
# 278145  100001      1
# 278146  100001      1
# 278147  100001      1
# 278148  100001      1
# 278149  100001      1
# 278150  100001      1
# 278151  100001      1
# 278152  100001      1
# 278153  100001      1
#
# [278154 rows x 19 columns]

# %%
#Churn by userid count
df_chrn_usr = df.groupBy("churn").agg(countDistinct("userId").alias("user-count"))
df_chrn_usr.show()
# Out:
# +-----+----------+
# |churn|user-count|
# +-----+----------+
# |    0|       173|
# |    1|        52|
# +-----+----------+

# %%
#Churn plot by user count
df_plot1=df_chrn_usr.toPandas()
plt.title("Distribution of Users by Churn")
sns.barplot(x="churn", y="user-count", data=df_plot1,palette="bright")
plt.show()

# %% [markdown]
# Expoloring submit downgrade events

# %%
#creating a temp view from dataframe df,so that we can use sparkSQL for quick easy analysis
df.createOrReplaceTempView('df_tbl')
downgrade_user = spark.sql("select distinct userId from df_tbl where page = 'Submit Downgrade'")
downgrade_user = downgrade_user.toPandas()['userId'].values

# %%
downgrade_user
# Out:
# array(['54', '11', '30', '59', '85', '35', '100008', '100025', '300002',
#        '96', '100', '61', '131', '140', '300004', '300015', '77', '100009',
#        '300011', '100004', '200003', '100015', '300023', '100016', '95',
#        '38', '103', '25', '200009', '200023', '92', '81', '100012',
#        '200025', '200020', '141', '9', '24', '20', '200011', '49',
#        '300021', '39', '12', '109', '13', '200019', '74', '100018'], dtype=object)

# %%
downgrade_udf = udf(lambda user: 1 if user in downgrade_user else 0, IntegerType())
spark.udf.register('downgrade_udf', downgrade_udf)
# Out:
# <function __main__.<lambda>(user)>

# %%
df_tbl_downgrade = spark.sql("""
    SELECT * ,
        downgrade_udf(userId) as downgrade_status
    FROM
        df_tbl
    """)

# %%
df_tbl_downgrade.select('userId',
        'downgrade_status',
        'churn').distinct().groupBy("churn")\
.agg((f.sum("downgrade_status")/f.countDistinct("userId"))).show()
# Out:
# +-----+------------------------------------------------+
# |churn|(sum(downgrade_status) / count(DISTINCT userId))|
# +-----+------------------------------------------------+
# |    0|                             0.23121387283236994|
# |    1|                             0.17307692307692307|
# +-----+------------------------------------------------+

# %% [markdown]
# No major difference is observed between submitting a downgrade for non-churned and churned users. From the data, Non-churned users are more frequently submitting for downgrades . As a result, submit downgrade will not be considered into features.

# %% [markdown]
# # Feature Engineering
# Once you've familiarized yourself with the data, build out the features you find promising to train your model on. To work with the full dataset, you can follow the following steps.
# - Write a script to extract the necessary features from the smaller subset of data
# - Ensure that your script is scalable, using the best practices discussed in Lesson 3
# - Try your script on the full data set, debugging your script if necessary
#
# If you are working in the classroom workspace, you can just extract features based on the small subset of data contained here. Be sure to transfer over this work to the larger dataset when you work on your Spark cluster.

# %%
# Convert timestamp
to_date = udf(lambda x: datetime.datetime.fromtimestamp(x/1000), DateType())
df = df.withColumn('timestamp', to_date(col('ts')))

# Create hour / day / month / year fields
#df = df.withColumn("hour", f.hour("timestamp"))
df = df.withColumn("day", f.dayofmonth("timestamp"))
df = df.withColumn("month", f.month("timestamp"))
df = df.withColumn("year", f.year("timestamp"))

def acc_active_days(x, y):
    """
    Retrieve rounded number of days since registration
    """
    sec_diff = f.when(x > y, x - y).otherwise(0)    
    return f.round(sec_diff / (1000 * 60 * 60 * 24))


# Days since registration
df = df.withColumn(
    'acc_active_days', acc_active_days(df.ts, df.registration)
)

# List of unique page entries
pages = [row.page for row in df.select(df.page).dropDuplicates().collect()]

# One hot encoding for pages
for page in pages:
    page_col = page.replace(" ", "")+"_page"
    df = df.withColumn(page_col, f.when(df.page == page, 1).otherwise(0))

# label encoding gender column
df = df.withColumn('gender_male', f.when(df.gender == 'M', 1).otherwise(0))

# label encoding level column
df = df.withColumn('paid_level', f.when(df.level == 'paid', 1).otherwise(0))
#df = df.withColumn("label", df["churn"].cast(DoubleType()))

# %%
#from pyspark.ml.feature import OneHotEncoderEstimator

#Index
#Gender_indexer = StringIndexer(inputCol="gender", outputCol='gender_idx')
#User_indexer = StringIndexer(inputCol="userAgent", outputCol='user_idx')
#page_indexer = StringIndexer(inputCol="page", outputCol="page_idx")
#level_indexer = StringIndexer(inputCol="level", outputCol="level_idx")


#Encode
#Gender_encoder = OneHotEncoderEstimator(inputCols=['gender_idx'], outputCols=['gender_Vec'])
#User_encoder = OneHotEncoderEstimator(inputCols=['user_idx'], outputCols=['user_Vec'])
#page_encoder = OneHotEncoderEstimator(inputCols=["page_idx"],outputCols=["page_Vec"])
#level_encoder = OneHotEncoderEstimator(inputCols=['level_idx'], outputCols=['level_Vec'])

# %%
df.printSchema()
# Out:
# root
#  |-- artist: string (nullable = true)
#  |-- auth: string (nullable = true)
#  |-- firstName: string (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- itemInSession: long (nullable = true)
#  |-- lastName: string (nullable = true)
#  |-- length: double (nullable = true)
#  |-- level: string (nullable = true)
#  |-- location: string (nullable = true)
#  |-- method: string (nullable = true)
#  |-- page: string (nullable = true)
#  |-- registration: long (nullable = true)
#  |-- sessionId: long (nullable = true)
#  |-- song: string (nullable = true)
#  |-- status: long (nullable = true)
#  |-- ts: long (nullable = true)
#  |-- userAgent: string (nullable = true)
#  |-- userId: string (nullable = true)
#  |-- churn: long (nullable = true)
#  |-- timestamp: date (nullable = true)
#  |-- day: integer (nullable = true)
#  |-- month: integer (nullable = true)
#  |-- year: integer (nullable = true)
#  |-- acc_active_days: double (nullable = true)
#  |-- Cancel_page: integer (nullable = false)
#  |-- SubmitDowngrade_page: integer (nullable = false)
#  |-- ThumbsDown_page: integer (nullable = false)
#  |-- Home_page: integer (nullable = false)
#  |-- Downgrade_page: integer (nullable = false)
#  |-- RollAdvert_page: integer (nullable = false)
#  |-- Logout_page: integer (nullable = false)
#  |-- SaveSettings_page: integer (nullable = false)
#  |-- CancellationConfirmation_page: integer (nullable = false)
#  |-- About_page: integer (nullable = false)
#  |-- Settings_page: integer (nullable = false)
#  |-- AddtoPlaylist_page: integer (nullable = false)
#  |-- AddFriend_page: integer (nullable = false)
#  |-- NextSong_page: integer (nullable = false)
#  |-- ThumbsUp_page: integer (nullable = false)
#  |-- Help_page: integer (nullable = false)
#  |-- Upgrade_page: integer (nullable = false)
#  |-- Error_page: integer (nullable = false)
#  |-- SubmitUpgrade_page: integer (nullable = false)
#  |-- gender_male: integer (nullable = false)
#  |-- paid_level: integer (nullable = false)

# %% [markdown]
# # Modeling
# Split the full dataset into train, test, and validation sets. Test out several of the machine learning methods you learned. Evaluate the accuracy of the various models, tuning parameters as necessary. Determine your winning model based on test accuracy and report results on the validation set. Since the churned users are a fairly small subset, I suggest using F1 score as the metric to optimize.

# %%
# Instantiate standard scaler
#scaler = StandardScaler(inputCol="input_features", outputCol="features", withStd=True)

# Split code for training / validation
train, test = df.randomSplit([0.75, 0.25], seed=80)

# %%
#Fit feature engineering into a pipeline as same preprocessing will be used across all models.

indexer = StringIndexer(inputCol="churn", outputCol="label")

#Feat_eng = Pipeline(stages=[Gender_indexer, User_indexer,level_indexer, Gender_encoder, User_encoder,level_encoder, indexer]);
#Feat_eng_trained = Feat_eng.fit(train)
#train = Feat_eng_trained.transform(train)

# %%
train.printSchema()
# Out:
# root
#  |-- artist: string (nullable = true)
#  |-- auth: string (nullable = true)
#  |-- firstName: string (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- itemInSession: long (nullable = true)
#  |-- lastName: string (nullable = true)
#  |-- length: double (nullable = true)
#  |-- level: string (nullable = true)
#  |-- location: string (nullable = true)
#  |-- method: string (nullable = true)
#  |-- page: string (nullable = true)
#  |-- registration: long (nullable = true)
#  |-- sessionId: long (nullable = true)
#  |-- song: string (nullable = true)
#  |-- status: long (nullable = true)
#  |-- ts: long (nullable = true)
#  |-- userAgent: string (nullable = true)
#  |-- userId: string (nullable = true)
#  |-- churn: long (nullable = true)
#  |-- timestamp: date (nullable = true)
#  |-- day: integer (nullable = true)
#  |-- month: integer (nullable = true)
#  |-- year: integer (nullable = true)
#  |-- acc_active_days: double (nullable = true)
#  |-- Cancel_page: integer (nullable = false)
#  |-- SubmitDowngrade_page: integer (nullable = false)
#  |-- ThumbsDown_page: integer (nullable = false)
#  |-- Home_page: integer (nullable = false)
#  |-- Downgrade_page: integer (nullable = false)
#  |-- RollAdvert_page: integer (nullable = false)
#  |-- Logout_page: integer (nullable = false)
#  |-- SaveSettings_page: integer (nullable = false)
#  |-- CancellationConfirmation_page: integer (nullable = false)
#  |-- About_page: integer (nullable = false)
#  |-- Settings_page: integer (nullable = false)
#  |-- AddtoPlaylist_page: integer (nullable = false)
#  |-- AddFriend_page: integer (nullable = false)
#  |-- NextSong_page: integer (nullable = false)
#  |-- ThumbsUp_page: integer (nullable = false)
#  |-- Help_page: integer (nullable = false)
#  |-- Upgrade_page: integer (nullable = false)
#  |-- Error_page: integer (nullable = false)
#  |-- SubmitUpgrade_page: integer (nullable = false)
#  |-- gender_male: integer (nullable = false)
#  |-- paid_level: integer (nullable = false)

# %%
# Create features vector
exclude_cols = ['artist', 'auth', 'firstName', 'gender', 'itemInSession', 'lastName',
                'level', 'location', 'method', 'page', 'registration', 'sessionId', 'song', 'status',
                'ts', 'userAgent', 'userId', 'timestamp', 'ts','churn','gender_idx',
               'user_idx','page_idx','level_idx']
feature_cols = [x for x in train.columns if x not in exclude_cols]

assembler = VectorAssembler(inputCols=feature_cols, outputCol="input_features", handleInvalid='skip')

# %%
#Final selected input columns
print(feature_cols)
# Out:
# ['length', 'day', 'month', 'year', 'acc_active_days', 'Cancel_page', 'SubmitDowngrade_page', 'ThumbsDown_page', 'Home_page', 'Downgrade_page', 'RollAdvert_page', 'Logout_page', 'SaveSettings_page', 'CancellationConfirmation_page', 'About_page', 'Settings_page', 'AddtoPlaylist_page', 'AddFriend_page', 'NextSong_page', 'ThumbsUp_page', 'Help_page', 'Upgrade_page', 'Error_page', 'SubmitUpgrade_page', 'gender_male', 'paid_level']

# %%
model_lrm = LogisticRegression(featuresCol="input_features", labelCol="label", maxIter=10, regParam=0.01)
model_rfm = RandomForestClassifier(featuresCol="input_features", labelCol="label")
model_gbm = GBTClassifier(featuresCol="input_features", labelCol="label",lossType='logistic', seed=8)

# %%
#Create Pipeline

pipeline_lrm = Pipeline(stages=[indexer, assembler, model_lrm]);
pipeline_rfm = Pipeline(stages=[indexer, assembler, model_rfm]);
pipeline_gbm = Pipeline(stages=[indexer, assembler, model_gbm]);

# %%
#Fit the model

start_time= time.time()
model_lr_fitted = pipeline_lrm.fit(train);
end_time= time.time()
print("logistic model exicute time:{}".format(end_time-start_time))

start_time= time.time()
model_rf_fitted = pipeline_rfm.fit(train);
end_time= time.time()
print("random forest model exicute time:{}".format(end_time-start_time))

start_time= time.time()
model_gbt_fitted = pipeline_gbm.fit(train)
end_time= time.time()
print("gradient boosting model exicute time:{}".format(end_time-start_time))
# Out:
# logistic model exicute time:94.37662935256958
# random forest model exicute time:119.37954616546631
# gradient boosting model exicute time:371.59114694595337

# %%
#Transform the model

#test = Feat_eng_trained.transform(test)

pred_lrm_fitted = model_lr_fitted.transform(test)
pred_rfm_fitted = model_rf_fitted.transform(test)
pred_gbm_fitted = model_gbt_fitted.transform(test)

# %%
#Create accuracy and f1 evaluators
acc_evaluator = MulticlassClassificationEvaluator(metricName = "accuracy",predictionCol="prediction",labelCol="churn");
f1_evaluator = MulticlassClassificationEvaluator(metricName = "f1",predictionCol="prediction",labelCol="churn");

# %%
#print Model Accuracy
print("Logistic Regression Classifier Accuracy:{}".format(acc_evaluator.evaluate(pred_lrm_fitted)));
print("Random Forest Classifier Accuracy:{}".format(acc_evaluator.evaluate(pred_rfm_fitted)));
print("GBTClassifier Classifier Accuracy:{}".format(acc_evaluator.evaluate(pred_gbm_fitted)));
# Out:
# Logistic Regression Classifier Accuracy:0.839322129245482
# Random Forest Classifier Accuracy:0.8393572885169819
# GBTClassifier Classifier Accuracy:0.8684164264116447

# %%
#print Model F1-Score
print("Logistic Regression Classifier F1-Score:{}".format(f1_evaluator.evaluate(pred_lrm_fitted)));
print("Random Forest Classifier F1-Score:{}".format(f1_evaluator.evaluate(pred_rfm_fitted)));
print("GBTClassifier Classifier F1-Score:{}".format(f1_evaluator.evaluate(pred_gbm_fitted)));
# Out:
# Logistic Regression Classifier F1-Score:0.7660334591687653
# Random Forest Classifier F1-Score:0.7660509050469619
# GBTClassifier Classifier F1-Score:0.8389763099713925

# %% [markdown]
# Model tuning - hyperparameters

# %%
#Create parmater grid
paramGrid = (ParamGridBuilder()
             .addGrid(model_gbm.maxDepth, [3,4])
             #.addGrid(model_gbm.maxIter, [25,30])
             .addGrid(model_gbm.stepSize,[0.1,0.09])
             .build())
#Perform crossvalidation
crossval = CrossValidator(estimator=pipeline_gbm,
                          estimatorParamMaps=paramGrid,
                          evaluator=MulticlassClassificationEvaluator(metricName = "f1"),
                          numFolds=2)
# fit and check performance
model_gbt_fitted_cv = crossval.fit(train)
pred_gbm_fitted_tune = model_gbt_fitted_cv.transform(test)
print("GBTClassifier  Classifier Accuracy:{}".format(acc_evaluator.evaluate(pred_gbm_fitted_tune)));
print("GBTClassifier  Classifier F1-Score:{}".format(f1_evaluator.evaluate(pred_gbm_fitted_tune)));
# Out:
# GBTClassifier  Classifier Accuracy:0.8634062302229097
# GBTClassifier  Classifier F1-Score:0.8298259088173815

# %% [markdown]
# # Final Steps
# Clean up your code, adding comments and renaming variables to make the code easier to read and maintain. Refer to the Spark Project Overview page and Data Scientist Capstone Project Rubric to make sure you are including all components of the capstone project and meet all expectations. Remember, this includes thorough documentation in a README file in a Github repository, as well as a web app or blog post.

# %% [markdown]
# # Conclusion
# ### Summary
# Model to predict customer churn is implemented in this notebook. In the process of Cleaning data rows with no userId were removed, converted gender, user, page, level using one-hot encoding, and added date and time-related columns to calculate the age of the accounts. Twenty six features were created/utilized for the model. Three models, logistic regression, Random Forest, and GBTClassifier, were used to predict churn. GBTClassifier has a better f1 score and accuracy in-comparison. For data preparation, StringIndexer, OneHotEncoderEstimator, and VectorAssembler were used to preprocessing or synthesizing new features. Since the churned users are limited, F1 score has been used for hyperparameter tuning.
#
# ### Reflections from this final project.
# This project has given exposure to spark environment to analyze a large volume of data that a personal laptop may not be capable of analyzing. By identifying a customer with a high chance to churn, companies can deploy value-adding strategies to retain customers by using targeted promotions and offers.
#
# One of the interesting yet challenging parts during the project is brainstorming for the new features that we can derive from the data we have on hand. Exploratory data analysis plays a vital role in understanding features and their relationships.
#
# As a recommendation, churn can be reduced by offering better content to users at a better price, intuitive UI, and family plans will let the user stay subscribed.
#
# ### Improvements
# The feature synthesis can be improved with more domain knowledge and expertise.
# Many ignored features can be converted into consumable form to identify if users are more likely to churn when they log in via mobile versus desktop. Predictive performance in relation to the average length of a given user’s session.
# A more robust feature set can be developed with more time.

# %%
from subprocess import call
call(['python', '-m', 'nbconvert', 'Sparkify.ipynb'])
# Out:
# 0
